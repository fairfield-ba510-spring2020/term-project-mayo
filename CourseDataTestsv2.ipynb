# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("sqlite:///CourseData.db")

# %%
print("-----------------------------------------------------------------------------")

print("                         instructor lookup")

print("-----------------------------------------------------------------------------")

input_instructor = input("Enter the instructor's last name")

input_year = input("Enter the year you wish to see or type in No to see all the years:").lower()
if input_year == "no" or  input_year == "n" or  input_year == "nah" :
    
    query = '''SELECT FACULTY.instructor_fname,FACULTY.instructor_lname,Title,Catalog_id,Section,Semester,Year
        FROM FACULTY
            JOIN COURSE_OFFERING USING(FID)
        WHERE FACULTY.instructor_lname like '%{}'
        ORDER BY Year, Semester
        LIMIT 20'''.format(input_instructor)
    tables = pd.read_sql_query(query,engine)

else :
    input_semester = input("Enter the semester you wish to see or type in No to see all the courses that the instructor is teaching in {0} :".format(input_year)).lower()
    if input_semester == "no" or  input_semester == "n" or  input_semester == "nah" :
        query = '''SELECT FACULTY.instructor_fname,FACULTY.instructor_lname,Title,Catalog_id,Section,Semester,Year
        FROM FACULTY
        JOIN COURSE_OFFERING USING(FID)
        WHERE FACULTY.instructor_lname like '%{0}' and year = {1}
        ORDER BY Year, Semester
        LIMIT 20'''.format(input_instructor , input_year )
        tables = pd.read_sql_query(query,engine)
    else:
        query = '''SELECT FACULTY.instructor_fname,FACULTY.instructor_lname,Title,Catalog_id,Section,Semester,Year
        FROM FACULTY
        JOIN COURSE_OFFERING USING(FID)
        WHERE FACULTY.instructor_lname like '%{0}' 
        AND year = {1}
        AND SEMESTER == '{2}'
        ORDER BY Year, Semester
        LIMIT 20'''.format(input_instructor ,
                           input_year , 
                           input_semester.capitalize() )
        tables = pd.read_sql_query(query,engine)
    


    

tables
# Out:
# -----------------------------------------------------------------------------
#                          instructor lookup
# -----------------------------------------------------------------------------
# Enter the instructor's last name tao
# Enter the year you wish to see or type in No to see all the years: no
#    instructor_fname instructor_lname  \
# 0               Jie              Tao
# 1               Jie              Tao
# 2               Jie              Tao
# 3               Jie              Tao
# 4               Jie              Tao
# 5               Jie              Tao
# 6               Jie              Tao
# 7               Jie              Tao
# 8               Jie              Tao
# 9               Jie              Tao
# 10              Jie              Tao
# 11              Jie              Tao
# 12              Jie              Tao
# 13              Jie              Tao
# 14              Jie              Tao
# 15              Jie              Tao
# 16              Jie              Tao
# 17              Jie              Tao
# 18              Jie              Tao
# 19              Jie              Tao
#
#                                                 TITLE CATALOG_ID SECTION  \
# 0                        Intro to Information Systems    IS 0100       C
# 1                        Intro to Information Systems    IS 0100       D
# 2                 Systems Analysis and Logical Design    IS 0240       A
# 3         Information Systems and Database Management    IS 0500      01
# 4                 Introduction to Information Systems    IS 0100      03
# 5                 Introduction to Information Systems    IS 0100      04
# 6                        Data Mining and Applications    IS 0315      01
# 7         Information Systems and Database Management    IS 0500      01
# 8   Independent Study in Information Systems and O...    IS 0598      JT
# 9                        Intro to Information Systems    IS 0100       D
# 10              Data Mining and Business Intelligence    IS 0540      01
# 11               Business Analytics and Big Data Mgmt    IS 0550      01
# 12  Contemporary Topics: Advanced Data Mining Appl...   IS 0585B      01
# 13                                  Independent Study    IS 0399      JT
# 14        Information Systems and Database Management    IS 0500      01
# 15              Data Mining and Business Intelligence    IS 0540      01
# 16               Business Analytics and Big Data Mgmt    IS 0550      01
# 17  Independent Study in Information Systems and O...    IS 0598      JT
# 18                Introduction to Information Systems    IS 0100      02
# 19                Introduction to Information Systems    IS 0100      04
#
#    SEMESTER  YEAR
# 0      Fall  2015
# 1      Fall  2015
# 2      Fall  2015
# 3    Summer  2015
# 4      Fall  2016
# 5      Fall  2016
# 6      Fall  2016
# 7      Fall  2016
# 8      Fall  2016
# 9    Spring  2016
# 10   Spring  2016
# 11   Spring  2016
# 12   Summer  2016
# 13   Spring  2017
# 14   Spring  2017
# 15   Spring  2017
# 16   Spring  2017
# 17   Spring  2017
# 18     Fall  2018
# 19     Fall  2018
